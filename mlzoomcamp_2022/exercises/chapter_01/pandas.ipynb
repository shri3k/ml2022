# %%
import pandas as pd

# %%
url = "raw.githubusercontent.com"
path = "/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv"

# %%
from http import client
conn = client.HTTPSConnection(url)
conn.request("GET", path)
resp = conn.getresponse()
df = pd.read_csv(resp)

# %% [markdown]
# # Data Accessing

# %%
df["Make"], df["Vehicle Size"]
# Out:
# (0            BMW
#  1            BMW
#  2            BMW
#  3            BMW
#  4            BMW
#            ...
#  11909      Acura
#  11910      Acura
#  11911      Acura
#  11912      Acura
#  11913    Lincoln
#  Name: Make, Length: 11914, dtype: object,
#  0        Compact
#  1        Compact
#  2        Compact
#  3        Compact
#  4        Compact
#            ...
#  11909    Midsize
#  11910    Midsize
#  11911    Midsize
#  11912    Midsize
#  11913    Midsize
#  Name: Vehicle Size, Length: 11914, dtype: object)

# %%
df[["Make", "Model", "Year"]]
# Out:
#           Make       Model  Year
# 0          BMW  1 Series M  2011
# 1          BMW    1 Series  2011
# 2          BMW    1 Series  2011
# 3          BMW    1 Series  2011
# 4          BMW    1 Series  2011
# ...        ...         ...   ...
# 11909    Acura         ZDX  2012
# 11910    Acura         ZDX  2012
# 11911    Acura         ZDX  2012
# 11912    Acura         ZDX  2013
# 11913  Lincoln      Zephyr  2006
#
# [11914 rows x 3 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11914, step=1)

# %%
# loc actually uses the index in the table instead of using positional index
df.loc[[1]]
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 1  BMW  1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1  Luxury,Performance      Compact   Convertible           28        19
#
#    Popularity   MSRP
# 1        3916  40650

# %%
# Re-structing the index
import numpy as np
df.index = np.random.randint(low=0,high=len(df), size=(len(df))) # randomizes the indices
df.loc[[1]] # Notice how this is different from above just because we re-structured the index
# Out:
#      Make Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1  Suzuki  XL-7  2004  regular unleaded      185.0               6.0
#
#   Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 1         AUTOMATIC  four wheel drive              4.0             NaN
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 1      Midsize       4dr SUV           20        15         481  24499

# %%
# To follow the positional index use `iloc`
df.iloc[[1]]
# Out:
#      Make     Model  Year             Engine Fuel Type  Engine HP  \
# 6173  BMW  1 Series  2011  premium unleaded (required)      300.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 6173               6.0            MANUAL  rear wheel drive              2.0
#
#          Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 6173  Luxury,Performance      Compact   Convertible           28        19
#
#       Popularity   MSRP
# 6173        3916  40650

# %% [markdown]
# # Element-wise oprations

# %%
for c in df.columns:
    print(c)
    print(df[c].unique())
    print('\n')
# Out:
# Make
# ['BMW' 'Audi' 'FIAT' 'Mercedes-Benz' 'Chrysler' 'Nissan' 'Volvo' 'Mazda'
#  'Mitsubishi' 'Ferrari' 'Alfa Romeo' 'Toyota' 'McLaren' 'Maybach'
#  'Pontiac' 'Porsche' 'Saab' 'GMC' 'Hyundai' 'Plymouth' 'Honda'
#  'Oldsmobile' 'Suzuki' 'Ford' 'Cadillac' 'Kia' 'Bentley' 'Chevrolet'
#  'Dodge' 'Lamborghini' 'Lincoln' 'Subaru' 'Volkswagen' 'Spyker' 'Buick'
#  'Acura' 'Rolls-Royce' 'Maserati' 'Lexus' 'Aston Martin' 'Land Rover'
#  'Lotus' 'Infiniti' 'Scion' 'Genesis' 'HUMMER' 'Tesla' 'Bugatti']
#
#
# Model
# ['1 Series M' '1 Series' '100' '124 Spider' '190-Class' '2 Series' '200'
#  '200SX' '240SX' '240' '2' '3 Series Gran Turismo' '3 Series' '300-Class'
#  '3000GT' '300' '300M' '300ZX' '323' '350-Class' '350Z' '360' '370Z' '3'
#  '4 Series Gran Coupe' '4 Series' '400-Class' '420-Class' '456M'
#  '458 Italia' '4C' '4Runner' '5 Series Gran Turismo' '5 Series'
#  '500-Class' '500e' '500' '500L' '500X' '550' '560-Class' '570S' '575M'
# ...

# %%
df[df["Year"] > 2012] # show all the cars that was manufactured after 2012
# Out:
#         Make     Model  Year                Engine Fuel Type  Engine HP  \
# 303      BMW  1 Series  2013     premium unleaded (required)      230.0
# 2896     BMW  1 Series  2013     premium unleaded (required)      300.0
# 6241     BMW  1 Series  2013     premium unleaded (required)      230.0
# 3967     BMW  1 Series  2013     premium unleaded (required)      300.0
# 10057    BMW  1 Series  2013     premium unleaded (required)      230.0
# ...      ...       ...   ...                             ...        ...
# 6667     BMW        Z4  2015     premium unleaded (required)      335.0
# 9602     BMW        Z4  2016     premium unleaded (required)      300.0
# 2131     BMW        Z4  2016     premium unleaded (required)      240.0
# 74       BMW        Z4  2016     premium unleaded (required)      335.0
# 10728  Acura       ZDX  2013  premium unleaded (recommended)      300.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
fuel = df[
    (df["city mpg"] > 50) & 
    (df["Engine Fuel Type"] == "electric")
]
fuel
# Out:
#                 Make                   Model  Year Engine Fuel Type  \
# 7809            FIAT                    500e  2015         electric
# 7544            FIAT                    500e  2016         electric
# 3201            FIAT                    500e  2017         electric
# 7521   Mercedes-Benz  B-Class Electric Drive  2015         electric
# 3634   Mercedes-Benz  B-Class Electric Drive  2016         electric
# ...              ...                     ...   ...              ...
# 7624       Chevrolet                Spark EV  2014         electric
# 10096      Chevrolet                Spark EV  2015         electric
# 8578       Chevrolet                Spark EV  2015         electric
# 3968       Chevrolet                Spark EV  2016         electric
# 4215       Chevrolet                Spark EV  2016         electric
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 7809         NaN               0.0      DIRECT_DRIVE  front wheel drive
# ...

# %% [markdown]
# ## Summarization of data

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.nunique()
# Out:
# Make                   48
# Model                 915
# Year                   28
# Engine Fuel Type       10
# Engine HP             356
# Engine Cylinders        9
# Transmission Type       5
# Driven_Wheels           4
# Number of Doors         3
# Market Category        71
# Vehicle Size            3
# Vehicle Style          16
# highway MPG            59
# city mpg               69
# Popularity             48
# MSRP                 6049
# dtype: int64

# %%
df.groupby("Make").Make.count().sort_values(ascending=False)
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
teslas = df[df["Make"] == "Tesla"]
teslas
# Out:
#         Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5256   Tesla  Model S  2014         electric        NaN               0.0
# 9005   Tesla  Model S  2014         electric        NaN               0.0
# 8978   Tesla  Model S  2014         electric        NaN               0.0
# 11051  Tesla  Model S  2014         electric        NaN               0.0
# 10292  Tesla  Model S  2015         electric        NaN               0.0
# 5006   Tesla  Model S  2015         electric        NaN               0.0
# 3319   Tesla  Model S  2015         electric        NaN               0.0
# 2596   Tesla  Model S  2015         electric        NaN               0.0
# 1714   Tesla  Model S  2015         electric        NaN               0.0
# 7223   Tesla  Model S  2016         electric        NaN               0.0
# 4411   Tesla  Model S  2016         electric        NaN               0.0
# 10454  Tesla  Model S  2016         electric        NaN               0.0
# ...

# %%
teslas.nunique()
# Out:
# Make                  1
# Model                 1
# Year                  3
# Engine Fuel Type      1
# Engine HP             0
# Engine Cylinders      1
# Transmission Type     1
# Driven_Wheels         2
# Number of Doors       1
# Market Category       2
# Vehicle Size          1
# Vehicle Style         1
# highway MPG          10
# city mpg             11
# Popularity            1
# MSRP                 16
# dtype: int64

# %%
df.head(n=3)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# ...

# %%
df.isnull()
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 441    False  False  False             False      False             False
# 6173   False  False  False             False      False             False
# 7028   False  False  False             False      False             False
# 2829   False  False  False             False      False             False
# 356    False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 1569   False  False  False             False      False             False
# 264    False  False  False             False      False             False
# 4957   False  False  False             False      False             False
# 10728  False  False  False             False      False             False
# 5405   False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64
